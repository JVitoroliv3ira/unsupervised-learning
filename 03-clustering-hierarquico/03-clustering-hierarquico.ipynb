# %%
# %pip install scipy
# %pip install seaborn
# Out:
# Requirement already satisfied: scipy in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (1.16.2)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from scipy) (2.3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/joao/dev/projetos/unsupervised-learning/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
iris = load_iris()

features = iris.feature_names

print(features)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
X = iris.data[:, [2, 3]]

X_scaled = StandardScaler().fit_transform(X)

# %%
Z = linkage(X_scaled, method='ward')

# %%
plt.figure(figsize=(10, 6))
dendrogram(Z, truncate_mode='level', p=5)
plt.title('Dendrograma - Hierarchical Clustering (ward linkage)')
plt.xlabel('Amostras')
plt.ylabel('Distância')
plt.show()

# %%
labels = fcluster(Z, t=3, criterion='maxclust')

sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=labels, palette='Set2')
plt.title('Clusters após corte do dendrograma')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
wine = load_wine()

features = wine.feature_names

print(features)
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %%
X = wine.data[:, [0, 6]]

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
Z = linkage(X_scaled, method='ward')

# %%
plt.figure(figsize=(10, 6))
dendrogram(Z, truncate_mode='level', p=5)
plt.title('Dendrograma - Hierarchical Clustering (ward linkage)')
plt.xlabel('Amostras')
plt.ylabel('Distância')
plt.show()

# %%
labels = fcluster(Z, t=3, criterion='maxclust')

sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=labels, palette='Set2')
plt.title('Clusters após corte do dendrograma')
plt.xlabel('alcohol')
plt.ylabel('flavanoids')
plt.show()
